# %% [markdown]
# #### import library

# %%
import pandas as pd
import numpy as np 
from matplotlib import pyplot as plt
import seaborn as sns

# plt.style.use('dark_background')

# %%
# plt.rcParams.update({
#     "lines.color": "white",
#     "patch.edgecolor": "white",
#     "text.color": "white",
#     "axes.facecolor": "black",
#     "axes.edgecolor": "white",
#     "axes.labelcolor": "white",
#     "xtick.color": "white",
#     "ytick.color": "white",
#     "grid.color": "grey",
#     "figure.facecolor": "black",
#     "figure.edgecolor": "black",
#     "savefig.facecolor": "black",
#     "savefig.edgecolor": "black"})

# %% [markdown]
# #### load dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dff = pd.read_csv('/content/drive/MyDrive/final-project-tesis/DATA/DATA_NEW.csv', encoding='utf-8')
df = dff[['HR_KUBIOS',	'HR_BEATS',	'RR_MS', 'RMSSD',	'STD_HR',	'STD_RR','VLF_MS2','LF_MS2', 'TOTAL_MS2','LF_PER_HF','VLF_HZ','LF_HZ','HF_HZ','LF_NU','HF_NU', 'class'	]]
df.head()
# Out:
#    HR_KUBIOS  HR_BEATS    RR_MS   RMSSD  STD_HR  STD_RR  VLF_MS2  LF_MS2  \
# 0     58.770     58.77  1021.66  30.930   1.731   28.33     1.32    2.96
# 1     60.310     60.48   994.72  62.190   3.270   49.91     0.61    2.47
# 2     61.114     61.17   981.76  26.855   1.820   29.94     0.53    6.37
# 3     59.710     59.71  1004.78  10.870   0.540    9.26     0.00    0.42
# 4     77.480     77.48   774.34   7.970   0.490    4.95     0.00    0.01
#
#    TOTAL_MS2  LF_PER_HF  VLF_HZ  LF_HZ  HF_HZ  LF_NU  HF_NU  class
# 0       7.17       1.03    0.03   0.06   0.31  50.66  49.34      1
# 1      14.28       0.22    0.03   0.14   0.17  18.10  81.90      1
# 2       8.16       5.03    0.03   0.09   0.22  83.43  16.57      1
# 3       0.59       2.43    0.00   0.09   0.31  70.87  29.13      1
# 4       0.09       0.13    0.00   0.06   0.35  11.40  88.60      1

# %% [markdown]
# #### normalisasi data

# %%
#function of normalization
def norm (x):
  #from sklearn import preprocessing
  import numpy as np
  hasil = (x-x.min())/(x.max()-x.min())
  return(hasil)

# %%
df = norm(df)

# %%
df.min()
# Out:
# HR_KUBIOS    0.0
# HR_BEATS     0.0
# RR_MS        0.0
# RMSSD        0.0
# STD_HR       0.0
# STD_RR       0.0
# VLF_MS2      0.0
# LF_MS2       0.0
# TOTAL_MS2    0.0
# LF_PER_HF    0.0
# VLF_HZ       0.0
# LF_HZ        0.0
# HF_HZ        0.0
# LF_NU        0.0
# HF_NU        0.0
# class        0.0
# dtype: float64

# %%
df.max()
# Out:
# HR_KUBIOS    1.0
# HR_BEATS     1.0
# RR_MS        1.0
# RMSSD        1.0
# STD_HR       1.0
# STD_RR       1.0
# VLF_MS2      1.0
# LF_MS2       1.0
# TOTAL_MS2    1.0
# LF_PER_HF    1.0
# VLF_HZ       1.0
# LF_HZ        1.0
# HF_HZ        1.0
# LF_NU        1.0
# HF_NU        1.0
# class        1.0
# dtype: float64

# %% [markdown]
# #### filtering data by class 0 and 1

# %%
df1 = df.loc[df['class']==1]
df0 = df.loc[df['class']==0]

# %% [markdown]
# #### ploting boxplot

# %%
# #ploting data boxplot
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# Set the figure size
plt.rcParams["figure.figsize"] = [10,5]
plt.rcParams["figure.autolayout"] = True

df = df1

# Pandas dataframe
data = pd.DataFrame({"HRBEATS": df['HR_BEATS'], "HRKUBIOS": df["HR_KUBIOS"], "RRMS": df["RR_MS"], "RMSSD": df["RMSSD"], "STD_HR": df["STD_HR"],"STD_RR": df["STD_RR"], "VLF_HZ": df["VLF_HZ"], "VLF_MS2": df["VLF_MS2"]})

# Plot the dataframe
ax = data[['HRBEATS', 'HRKUBIOS', 'RRMS', 'RMSSD', 'STD_HR',"STD_RR", 'VLF_HZ', 'VLF_MS2']].plot(kind='box', title='boxplot')

# Display the plot
plt.show()

# %%
# #ploting data boxplot
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# Set the figure size
plt.rcParams["figure.figsize"] = [10,5]
plt.rcParams["figure.autolayout"] = True

df = df0

# Pandas dataframe
data = pd.DataFrame({"HRBEATS": df['HR_BEATS'], "HRKUBIOS": df["HR_KUBIOS"], "RRMS": df["RR_MS"], "RMSSD": df["RMSSD"], "STD_HR": df["STD_HR"],"STD_RR": df["STD_RR"], "VLF_HZ": df["VLF_HZ"],  "VLF_MS2": df["VLF_MS2"]})

# Plot the dataframe
ax = data[['HRBEATS', 'HRKUBIOS', 'RRMS', 'RMSSD', 'STD_HR',"STD_RR", 'VLF_HZ', 'VLF_MS2']].plot(kind='box', title='boxplot')

# Display the plot
plt.show()

# %% [markdown]
# #### Ploting ref

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.signal import find_peaks
from scipy import signal
from scipy.integrate import trapz
from scipy.interpolate import interp1d
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dff = pd.read_csv('/content/drive/MyDrive/final-project-tesis/DATA/DATA_HIGH.csv', encoding='utf-8')
dfh = dff[['HR_KUBIOS',	'HR_BEATS',	'RR_MS', 'RMSSD',	'STD_HR',	'STD_RR','VLF_MS2','LF_MS2', 'TOTAL_MS2','LF_PER_HF','VLF_HZ','LF_HZ','HF_HZ','LF_NU','HF_NU', 'class'	]]
dfh.head()
# Out:
#    HR_KUBIOS  HR_BEATS    RR_MS   RMSSD  STD_HR  STD_RR  VLF_MS2  LF_MS2  \
# 0     58.770     58.77  1021.66  30.930   1.731   28.33     1.32    2.96
# 1     60.310     60.48   994.72  62.190   3.270   49.91     0.61    2.47
# 2     61.114     61.17   981.76  26.855   1.820   29.94     0.53    6.37
# 3     59.710     59.71  1004.78  10.870   0.540    9.26     0.00    0.42
# 4     77.480     77.48   774.34   7.970   0.490    4.95     0.00    0.01
#
#    TOTAL_MS2  LF_PER_HF  VLF_HZ  LF_HZ  HF_HZ  LF_NU  HF_NU  class
# 0       7.17       1.03    0.03   0.06   0.31  50.66  49.34      1
# 1      14.28       0.22    0.03   0.14   0.17  18.10  81.90      1
# 2       8.16       5.03    0.03   0.09   0.22  83.43  16.57      1
# 3       0.59       2.43    0.00   0.09   0.31  70.87  29.13      1
# 4       0.09       0.13    0.00   0.06   0.35  11.40  88.60      1

# %%
dff = pd.read_csv('/content/drive/MyDrive/final-project-tesis/DATA/DATA_NORM.csv', encoding='utf-8')
dfn = dff[['HR_KUBIOS',	'HR_BEATS',	'RR_MS', 'RMSSD',	'STD_HR',	'STD_RR','VLF_MS2','LF_MS2', 'TOTAL_MS2','LF_PER_HF','VLF_HZ','LF_HZ','HF_HZ','LF_NU','HF_NU', 'class'	]]
dfn.head()
# Out:
#    HR_KUBIOS  HR_BEATS    RR_MS   RMSSD  STD_HR  STD_RR  VLF_MS2  LF_MS2  \
# 0      52.63     52.93  1140.00  147.63    3.94   88.14     0.00    6.52
# 1      51.66     52.21  1161.37  179.12    5.48  118.16     1.16   15.11
# 2      52.06     53.21  1152.41  272.23    8.30  162.74     0.70    7.09
# 3      49.96     50.57  1200.76  242.96    5.57  131.67     0.68    8.88
# 4      56.78     56.79  1056.66   18.16    0.67   12.47     0.00    0.29
#
#    TOTAL_MS2  LF_PER_HF  VLF_HZ  LF_HZ  HF_HZ  LF_NU  HF_NU  class
# 0      45.26       0.17    0.00   0.05   0.32  14.40  85.60      0
# 1      80.71       0.23    0.03   0.12   0.18  18.99  81.01      0
# 2     110.15       0.07    0.03   0.12   0.34   6.48  93.52      0
# 3     101.66       0.10    0.03   0.13   0.36   8.80  91.20      0
# 4       0.82       0.56    0.00   0.14   0.19  35.83  64.17      0

# %%
#function of normalization
def norm (x):
  #from sklearn import preprocessing
  import numpy as np
  hasil = (x-x.min())/(x.max()-x.min())
  return(hasil)

# %%
# normalisasi data
dfhi = norm(dfh)
# menampilkan data
dfhi.head()
# Out:
#    HR_KUBIOS  HR_BEATS     RR_MS     RMSSD    STD_HR    STD_RR   VLF_MS2  \
# 0   0.112663  0.206826  0.610324  0.047257  0.010583  0.074578  0.025162
# 1   0.122098  0.213289  0.587708  0.095019  0.019991  0.131387  0.011628
# 2   0.127023  0.215897  0.576828  0.041031  0.011127  0.078816  0.010103
# 3   0.118422  0.210379  0.596153  0.016608  0.003301  0.024377  0.000000
# 4   0.227287  0.277545  0.402697  0.012177  0.002996  0.013031  0.000000
#
#      LF_MS2  TOTAL_MS2  LF_PER_HF  VLF_HZ     LF_HZ  HF_HZ     LF_NU  \
# 0  0.013954   0.007428   0.055435    0.75  0.181818   0.64  0.528338
# 1  0.011644   0.014793   0.011413    0.75  0.909091   0.08  0.180809
# 2  0.030030   0.008453   0.272826    0.75  0.454545   0.28  0.878109
# 3  0.001980   0.000611   0.131522    0.00  0.454545   0.64  0.744050
# 4  0.000047   0.000093   0.006522    0.00  0.181818   0.80  0.109297
#
#       HF_NU  class
# 0  0.471662    NaN
# 1  0.819191    NaN
# 2  0.121891    NaN
# 3  0.255950    NaN
# ...

# %%
# normalisasi data
dfno = norm(dfn)
# menampilkan data
dfno.head()
# Out:
#    HR_KUBIOS  HR_BEATS     RR_MS     RMSSD    STD_HR    STD_RR   VLF_MS2  \
# 0   0.203860  0.079238  0.518236  0.093647  0.084695  0.074443  0.000000
# 1   0.193101  0.071528  0.535073  0.113622  0.117799  0.099797  0.041877
# 2   0.197538  0.082236  0.528013  0.172684  0.178418  0.137449  0.025271
# 3   0.174246  0.053967  0.566108  0.154117  0.119733  0.111208  0.024549
# 4   0.249889  0.120570  0.452573  0.011519  0.014402  0.010532  0.000000
#
#      LF_MS2  TOTAL_MS2  LF_PER_HF  VLF_HZ     LF_HZ  HF_HZ     LF_NU  \
# 0  0.065449   0.175569   0.012143    0.00  0.090909   0.68  0.154291
# 1  0.151676   0.313084   0.016429    0.75  0.727273   0.12  0.203472
# 2  0.071170   0.427286   0.005000    0.75  0.727273   0.76  0.069431
# 3  0.089139   0.394352   0.007143    0.75  0.818182   0.84  0.094289
# 4  0.002911   0.003181   0.040000    0.00  0.909091   0.16  0.383907
#
#       HF_NU  class
# 0  0.845709    NaN
# 1  0.796528    NaN
# 2  0.930569    NaN
# 3  0.905711    NaN
# ...

# %%
# #ploting data boxplot
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# Set the figure size
plt.rcParams["figure.figsize"] = [10,5]
plt.rcParams["figure.autolayout"] = True

df = dfhi

# Pandas dataframe
data = pd.DataFrame({"HRBEATS": df['HR_BEATS'], "HRKUBIOS": df["HR_KUBIOS"], "RRMS": df["RR_MS"], "RMSSD": df["RMSSD"], "STD_HR": df["STD_HR"],"STD_RR": df["STD_RR"], "VLF_HZ": df["VLF_HZ"], "VLF_MS2": df["VLF_MS2"]})

# Plot the dataframe
ax = data[['HRBEATS', 'HRKUBIOS', 'RRMS', 'RMSSD', 'STD_HR',"STD_RR", 'VLF_HZ', 'VLF_MS2']].plot(kind='box', title='boxplot')

# Display the plot
plt.show()

# %%
# #ploting data boxplot
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# Set the figure size
plt.rcParams["figure.figsize"] = [15,5]
plt.rcParams["figure.autolayout"] = True

df = dfno
dff= dfhi

# Pandas dataframe
data = pd.DataFrame({"HRBEATS0": df['HR_BEATS'],"HRBEATS1": dff['HR_BEATS'], "HRKUBIOS0": df["HR_KUBIOS"], "HRKUBIOS1": dff["HR_KUBIOS"], "RMSSD0": df["RMSSD"],"RMSSD1": dff["RMSSD"], "STD_HR0": df["STD_HR"], "STD_HR1": dff["STD_HR"],"STD_RR0": df["STD_RR"], "STD_RR1": dff["STD_RR"], "VLF_HZ0": df["VLF_HZ"], "VLF_HZ1": dff["VLF_HZ"],"VLF_MS20": df["VLF_MS2"], "VLF_MS21": dff["VLF_MS2"],"VLF_HZ0": df["VLF_HZ"], "VLF_HZ1": dff["VLF_HZ"]})

# Plot the dataframe
ax = data[['HRBEATS0', 'HRBEATS1', 'HRKUBIOS0', 'HRKUBIOS1', 'RMSSD0', 'RMSSD1', 'STD_HR0', 'STD_HR1', 'STD_RR0', 'STD_RR1', 'VLF_MS20','VLF_MS21', 'VLF_HZ0','VLF_HZ1']].plot(kind='box')

# Display the plot
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
# #ploting data boxplot
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# Set the figure size
plt.rcParams["figure.figsize"] = [15,5]
plt.rcParams["figure.autolayout"] = True

df = dfno
dff= dfhi

# Pandas dataframe
data = pd.DataFrame({"HRBEATS0": df['HR_BEATS'],"HRBEATS1": dff['HR_BEATS'], "HRKUBIOS0": df["HR_KUBIOS"], "HRKUBIOS1": dff["HR_KUBIOS"], "RRMS0": df["RR_MS"], "RRMS1": dff["RR_MS"], "RMSSD0": df["RMSSD"],"RMSSD1": dff["RMSSD"], "STD_HR0": df["STD_HR"], "STD_HR1": dff["STD_HR"],"STD_RR0": df["STD_RR"], "STD_RR1": dff["STD_RR"], "VLF_HZ0": df["VLF_HZ"], "VLF_HZ1": dff["VLF_HZ"],"VLF_MS20": df["VLF_MS2"], "VLF_MS21": dff["VLF_MS2"]})

# Plot the dataframe
ax = data[['VLF_HZ0','VLF_HZ1', 'VLF_MS20','VLF_MS21']].plot(kind='box')

# Display the plot
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
